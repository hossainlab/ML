# %% [markdown]
# # Handling Missing Values

# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
df.isna().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
import missingno as ms 
ms.bar(df);

# %%
ms.matrix(df);

# %%
# removing missig values 
df_new = df.dropna()

# %%
df_new
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.shape, df_new.shape
# Out:
# ((10, 4), (8, 4))

# %%
df.Salary.mean()
# Out:
# 63777.77777777778

# %%
df.Salary.median()
# Out:
# 61000.0

# %%
# impute missing values 
df.fillna(df['Salary'].mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1534         try:
# -> 1535             x = float(x)
#    1536         except ValueError:
#
# ValueError: could not convert string to float: 'FranceSpainGermanySpainGermanyFranceSpainFranceGermanyFrance'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1538             try:
# -> 1539                 x = complex(x)
#    1540             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-1145b0a9e97b> in <module>
#       1 # impute missing values
# ----> 2 df.fillna(df['Salary'].mean(), inplace=True)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11111         )
#   11112         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11113             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11114
#   11115         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10719
#   10720     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10721         return self._stat_function(
#   10722             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10723         )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10704         if level is not None:
#   10705             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 10706         return self._reduce(
#   10707             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10708         )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4177                 )
#    4178             with np.errstate(all="ignore"):
# -> 4179                 return op(delegate, skipna=skipna, **kwds)
#    4180
#    4181     def _reindex_indexer(self, new_index, indexer, copy):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     131                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     132             else:
# --> 133                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     134
#     135             return result
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     390             mask = isna(values)
#     391
# --> 392         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     393
#     394         if datetimelike:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     629
#     630     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 631     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     632
#     633     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1540             except ValueError as err:
#    1541                 # e.g. "foo"
# -> 1542                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1543     return x
#    1544
#
# TypeError: Could not convert FranceSpainGermanySpainGermanyFranceSpainFranceGermanyFrance to numeric

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0   France        No
# 1    Spain  27.0    Spain       Yes
# 2  Germany  30.0  Germany        No
# 3    Spain  38.0    Spain        No
# 4  Germany  40.0  Germany       Yes
# 5   France  35.0   France       Yes
# 6    Spain   NaN    Spain        No
# 7   France  48.0   France       Yes
# 8  Germany  50.0  Germany        No
# 9   France  37.0   France       Yes

# %%
df = df.fillna(df['Age'].mean())
